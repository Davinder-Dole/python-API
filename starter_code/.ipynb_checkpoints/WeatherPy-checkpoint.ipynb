# %% [markdown]
# # WeatherPy
# ----
#
# ### Analysis
# * As expected, the weather becomes significantly warmer as one approaches the equator (0 Deg. Latitude). More interestingly, however, is the fact that the southern hemisphere tends to be warmer this time of year than the northern hemisphere. This may be due to the tilt of the earth.
# * There is no strong relationship between latitude and cloudiness. However, it is interesting to see that a strong band of cities sits at 0, 80, and 100% cloudiness.
# * There is no strong relationship between latitude and wind speed. However, in northern hemispheres there is a flurry of cities with over 20 mph of wind.
#
# ---
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
from datetime import datetime
import json

# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []



# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)
        
# Print the city count to confirm sufficient count
print(len(cities))
# Out:
# 591

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
base_url = "http://api.openweathermap.org/data/2.5/weather?"
api_key = api_key
units = "imperial"
query_url = base_url + "appid=" + api_key + "&units=" + units + "&q="

search_data=[]
cityList = []
countryList = []

searchCnt = 0
print("Beginning Data Retrieval")
print("---------------------------------------")
for city in cities:
    searchCnt += 1
    response= requests.get(query_url + city).json()
    print(f"Processing record {searchCnt} : {city}") 
    searchCityID = response.get("id")
    if response.get("id"):
        search_data.append(response)
        cityList.append(city)
        countryList.append(cities[searchCnt-1])
    else:
        print(f"City not found. Skipping...: {city}")
          
print("---------------------------------------")
print("Processing Complete")
# Out:
# Beginning Data Retrieval
# ---------------------------------------
# Processing record 1 : cascais
# Processing record 2 : talara
# Processing record 3 : port blair
# Processing record 4 : castro
# Processing record 5 : katsuura
# Processing record 6 : petropavlovsk-kamchatskiy
# Processing record 7 : tiksi
# Processing record 8 : hilo
# Processing record 9 : bambous virieux
# Processing record 10 : albany
# Processing record 11 : busselton
# Processing record 12 : yanam
# Processing record 13 : ponta do sol
# Processing record 14 : talcahuano
# Processing record 15 : barrow
# Processing record 16 : kapaa
# Processing record 17 : mar del plata
# Processing record 18 : brigantine
# Processing record 19 : broken hill
# Processing record 20 : moose factory
# Processing record 21 : aykhal
# Processing record 22 : acolla
# Processing record 23 : edd
# Processing record 24 : east london
# Processing record 25 : grand river south east
# City not found. Skipping...: grand river south east
# Processing record 26 : mataura
# Processing record 27 : lompoc
# Processing record 28 : qaanaaq
# Processing record 29 : stornoway
# City not found. Skipping...: stornoway
# Processing record 30 : bluff
# Processing record 31 : chicama
# Processing record 32 : flinders
# Processing record 33 : tidman
# Processing record 34 : salalah
# Processing record 35 : kargasok
# Processing record 36 : sulangan
# Processing record 37 : avarua
# Processing record 38 : utiroa
# City not found. Skipping...: utiroa
# Processing record 39 : kutum
# Processing record 40 : puerto ayora
# Processing record 41 : tuktoyaktuk
# Processing record 42 : christchurch
# Processing record 43 : san rafael
# Processing record 44 : tongliao
# Processing record 45 : san quintin
# Processing record 46 : phayao
# Processing record 47 : karauzyak
# City not found. Skipping...: karauzyak
# Processing record 48 : poum
# Processing record 49 : ushuaia
# Processing record 50 : taybad
# Processing record 51 : taolanaro
# City not found. Skipping...: taolanaro
# Processing record 52 : berlevag
# Processing record 53 : faanui
# Processing record 54 : vaini
# Processing record 55 : bambanglipuro
# Processing record 56 : saint george
# Processing record 57 : zyryanka
# Processing record 58 : manono
# Processing record 59 : punta arenas
# Processing record 60 : zhaotong
# Processing record 61 : nanakuli
# Processing record 62 : magadan
# Processing record 63 : savannah bight
# Processing record 64 : hermanus
# Processing record 65 : chumikan
# Processing record 66 : port alfred
# Processing record 67 : rikitea
# Processing record 68 : scarborough
# Processing record 69 : kizu
# City not found. Skipping...: kizu
# Processing record 70 : sault sainte marie
# Processing record 71 : mahebourg
# Processing record 72 : maloy
# Processing record 73 : talesh
# City not found. Skipping...: talesh
# Processing record 74 : atuona
# Processing record 75 : rocha
# Processing record 76 : atoyac
# Processing record 77 : sataua
# City not found. Skipping...: sataua
# Processing record 78 : attawapiskat
# City not found. Skipping...: attawapiskat
# Processing record 79 : iberia
# Processing record 80 : barra patuca
# Processing record 81 : kodiak
# Processing record 82 : amga
# Processing record 83 : faya
# Processing record 84 : saint anthony
# Processing record 85 : aasiaat
# Processing record 86 : kirakira
# Processing record 87 : yellowknife
# Processing record 88 : paamiut
# Processing record 89 : dese
# Processing record 90 : kropotkin
# Processing record 91 : pisco
# Processing record 92 : ialibu
# Processing record 93 : sala consilina
# Processing record 94 : nanortalik
# Processing record 95 : vestmannaeyjar
# Processing record 96 : chuy
# Processing record 97 : saskylakh
# Processing record 98 : port hardy
# Processing record 99 : hobart
# Processing record 100 : lavrentiya
# Processing record 101 : hasaki
# Processing record 102 : mahina
# Processing record 103 : fairbanks
# Processing record 104 : mount isa
# Processing record 105 : hami
# Processing record 106 : noumea
# Processing record 107 : risod
# Processing record 108 : villazon
# City not found. Skipping...: villazon
# Processing record 109 : abha
# Processing record 110 : nieuw amsterdam
# Processing record 111 : verkhnetulomskiy
# Processing record 112 : kruisfontein
# Processing record 113 : qasigiannguit
# Processing record 114 : la ronge
# Processing record 115 : lebu
# Processing record 116 : plettenberg bay
# Processing record 117 : nikolskoye
# Processing record 118 : asau
# City not found. Skipping...: asau
# Processing record 119 : chagda
# City not found. Skipping...: chagda
# Processing record 120 : torbay
# Processing record 121 : dhidhdhoo
# Processing record 122 : clyde river
# Processing record 123 : vardo
# Processing record 124 : huilong
# Processing record 125 : barentsburg
# City not found. Skipping...: barentsburg
# Processing record 126 : carnarvon
# Processing record 127 : sentyabrskiy
# City not found. Skipping...: sentyabrskiy
# Processing record 128 : lengshuitan
# Processing record 129 : itarema
# Processing record 130 : norman wells
# Processing record 131 : jamestown
# Processing record 132 : saint-pierre
# Processing record 133 : belushya guba
# City not found. Skipping...: belushya guba
# Processing record 134 : cherskiy
# Processing record 135 : kegayli
# City not found. Skipping...: kegayli
# Processing record 136 : russell
# Processing record 137 : khatanga
# Processing record 138 : qiryat shemona
# Processing record 139 : veydelevka
# Processing record 140 : ukiah
# Processing record 141 : cabo san lucas
# Processing record 142 : andros town
# Processing record 143 : kaitangata
# Processing record 144 : doka
# Processing record 145 : tilichiki
# Processing record 146 : port elizabeth
# Processing record 147 : pacific grove
# Processing record 148 : tasiilaq
# Processing record 149 : port lincoln
# Processing record 150 : sur
# Processing record 151 : mys shmidta
# City not found. Skipping...: mys shmidta
# Processing record 152 : villavieja
# Processing record 153 : qaqortoq
# Processing record 154 : ballina
# Processing record 155 : provideniya
# Processing record 156 : watsa
# Processing record 157 : lagoa
# Processing record 158 : paradwip
# City not found. Skipping...: paradwip
# Processing record 159 : swan hill
# Processing record 160 : cockburn town
# Processing record 161 : strezhevoy
# Processing record 162 : avera
# Processing record 163 : chara
# Processing record 164 : rehoboth
# Processing record 165 : constitucion
# Processing record 166 : tsihombe
# City not found. Skipping...: tsihombe
# Processing record 167 : nkhata bay
# Processing record 168 : yumen
# Processing record 169 : ancud
# Processing record 170 : chokurdakh
# Processing record 171 : georgetown
# Processing record 172 : cape town
# Processing record 173 : nisia floresta
# Processing record 174 : mayor pablo lagerenza
# Processing record 175 : honningsvag
# Processing record 176 : magrath
# Processing record 177 : tidore
# City not found. Skipping...: tidore
# Processing record 178 : thompson
# Processing record 179 : ilulissat
# Processing record 180 : marcona
# City not found. Skipping...: marcona
# Processing record 181 : cidreira
# Processing record 182 : mangan
# Processing record 183 : mergui
# City not found. Skipping...: mergui
# Processing record 184 : ostrovnoy
# Processing record 185 : amapa
# Processing record 186 : new norfolk
# Processing record 187 : bom jesus
# Processing record 188 : hailar
# Processing record 189 : klaksvik
# Processing record 190 : arman
# Processing record 191 : warqla
# City not found. Skipping...: warqla
# Processing record 192 : havoysund
# Processing record 193 : bowen
# Processing record 194 : alepe
# Processing record 195 : suihua
# Processing record 196 : san patricio
# Processing record 197 : santiago del estero
# Processing record 198 : bethel
# Processing record 199 : upata
# Processing record 200 : pontinia
# Processing record 201 : daru
# Processing record 202 : cradock
# Processing record 203 : brokopondo
# Processing record 204 : almaznyy
# Processing record 205 : wasilla
# Processing record 206 : kopervik
# Processing record 207 : pasni
# Processing record 208 : bredasdorp
# Processing record 209 : sitka
# Processing record 210 : talnakh
# Processing record 211 : butaritari
# Processing record 212 : nhulunbuy
# Processing record 213 : demyansk
# Processing record 214 : begijnendijk
# Processing record 215 : alofi
# Processing record 216 : kabo
# Processing record 217 : toliary
# City not found. Skipping...: toliary
# Processing record 218 : altay
# Processing record 219 : acapulco
# Processing record 220 : maceio
# Processing record 221 : hithadhoo
# Processing record 222 : hamilton
# Processing record 223 : dzhusaly
# City not found. Skipping...: dzhusaly
# Processing record 224 : beringovskiy
# Processing record 225 : sioux lookout
# Processing record 226 : yambio
# City not found. Skipping...: yambio
# Processing record 227 : tabiauea
# City not found. Skipping...: tabiauea
# Processing record 228 : varhaug
# Processing record 229 : lysva
# Processing record 230 : ribeira grande
# Processing record 231 : tiarei
# Processing record 232 : uyuni
# Processing record 233 : oloron-sainte-marie
# Processing record 234 : raudeberg
# Processing record 235 : illoqqortoormiut
# City not found. Skipping...: illoqqortoormiut
# Processing record 236 : santa cruz do sul
# Processing record 237 : tanete
# Processing record 238 : egvekinot
# Processing record 239 : evensk
# Processing record 240 : isangel
# Processing record 241 : fuerte olimpo
# Processing record 242 : bolshevik
# Processing record 243 : ratnagiri
# Processing record 244 : ilinsko-podomskoye
# City not found. Skipping...: ilinsko-podomskoye
# Processing record 245 : ponta delgada
# Processing record 246 : comodoro rivadavia
# Processing record 247 : amderma
# City not found. Skipping...: amderma
# Processing record 248 : rungata
# City not found. Skipping...: rungata
# Processing record 249 : soavinandriana
# Processing record 250 : yulara
# Processing record 251 : sawakin
# Processing record 252 : sanandaj
# Processing record 253 : turukhansk
# Processing record 254 : peace river
# Processing record 255 : uwayl
# City not found. Skipping...: uwayl
# Processing record 256 : safford
# Processing record 257 : new bern
# Processing record 258 : atar
# Processing record 259 : hay river
# Processing record 260 : lemesos
# City not found. Skipping...: lemesos
# Processing record 261 : dikson
# Processing record 262 : merke
# Processing record 263 : nyaunglebin
# Processing record 264 : turka
# Processing record 265 : karratha
# Processing record 266 : puerto ayacucho
# Processing record 267 : mizdah
# Processing record 268 : pousat
# City not found. Skipping...: pousat
# Processing record 269 : port macquarie
# Processing record 270 : biak
# Processing record 271 : aitape
# Processing record 272 : santa maria
# Processing record 273 : sabha
# Processing record 274 : porto novo
# Processing record 275 : leningradskiy
# Processing record 276 : bac lieu
# City not found. Skipping...: bac lieu
# Processing record 277 : zhezkazgan
# Processing record 278 : matadi
# Processing record 279 : laurel
# Processing record 280 : coquimbo
# Processing record 281 : esperance
# Processing record 282 : saint-philippe
# Processing record 283 : sao joao da barra
# Processing record 284 : aklavik
# Processing record 285 : coihaique
# Processing record 286 : makakilo city
# Processing record 287 : barcelos
# Processing record 288 : mollendo
# Processing record 289 : fare
# Processing record 290 : kyra
# City not found. Skipping...: kyra
# Processing record 291 : mnogovershinnyy
# Processing record 292 : macamic
# Processing record 293 : quatre cocos
# Processing record 294 : saint-junien
# Processing record 295 : upernavik
# Processing record 296 : padang
# Processing record 297 : ushumun
# Processing record 298 : iqaluit
# Processing record 299 : terney
# Processing record 300 : khor
# Processing record 301 : shingu
# Processing record 302 : haapu
# City not found. Skipping...: haapu
# Processing record 303 : gizo
# Processing record 304 : asfi
# City not found. Skipping...: asfi
# Processing record 305 : praia da vitoria
# Processing record 306 : koslan
# Processing record 307 : buala
# Processing record 308 : katsiveli
# City not found. Skipping...: katsiveli
# Processing record 309 : ndioum
# Processing record 310 : funadhoo
# Processing record 311 : ambon
# Processing record 312 : ailigandi
# Processing record 313 : tessalit
# Processing record 314 : bubaque
# Processing record 315 : newport
# Processing record 316 : saldanha
# Processing record 317 : chengmai
# City not found. Skipping...: chengmai
# Processing record 318 : nador
# Processing record 319 : maniitsoq
# Processing record 320 : sumbawa
# City not found. Skipping...: sumbawa
# Processing record 321 : fortuna
# Processing record 322 : fuengirola
# Processing record 323 : irupi
# Processing record 324 : grindavik
# Processing record 325 : anadyr
# Processing record 326 : severo-kurilsk
# Processing record 327 : mecca
# Processing record 328 : ramgarh
# Processing record 329 : bentong
# Processing record 330 : goderich
# Processing record 331 : nome
# Processing record 332 : ust-maya
# Processing record 333 : cagayan de tawi-tawi
# City not found. Skipping...: cagayan de tawi-tawi
# Processing record 334 : penarroya-pueblonuevo
# Processing record 335 : nizhneyansk
# City not found. Skipping...: nizhneyansk
# Processing record 336 : miandrivazo
# Processing record 337 : san policarpo
# Processing record 338 : yerbogachen
# Processing record 339 : bure
# Processing record 340 : takoradi
# Processing record 341 : burnie
# Processing record 342 : donskoy
# Processing record 343 : pevek
# Processing record 344 : gyanpur
# Processing record 345 : sembakung
# Processing record 346 : ijaki
# City not found. Skipping...: ijaki
# Processing record 347 : karaul
# City not found. Skipping...: karaul
# Processing record 348 : dali
# Processing record 349 : burica
# City not found. Skipping...: burica
# Processing record 350 : lasa
# Processing record 351 : kulhudhuffushi
# Processing record 352 : palabuhanratu
# City not found. Skipping...: palabuhanratu
# Processing record 353 : victor harbor
# Processing record 354 : jiguani
# Processing record 355 : gilgit
# Processing record 356 : saleaula
# City not found. Skipping...: saleaula
# Processing record 357 : bataipora
# Processing record 358 : galle
# Processing record 359 : guerrero negro
# Processing record 360 : college
# Processing record 361 : rosarito
# Processing record 362 : french harbor
# Processing record 363 : solnechnogorsk
# Processing record 364 : fjerritslev
# Processing record 365 : mount gambier
# Processing record 366 : mezen
# Processing record 367 : okato
# Processing record 368 : normandin
# Processing record 369 : dauphin
# Processing record 370 : thanh hoa
# Processing record 371 : sabang
# Processing record 372 : liepaja
# Processing record 373 : san cristobal
# Processing record 374 : povenets
# Processing record 375 : realeza
# Processing record 376 : borama
# City not found. Skipping...: borama
# Processing record 377 : baker city
# Processing record 378 : broome
# Processing record 379 : the valley
# Processing record 380 : souillac
# Processing record 381 : potosi
# Processing record 382 : kavaratti
# Processing record 383 : henties bay
# Processing record 384 : hobyo
# Processing record 385 : hambantota
# Processing record 386 : rudnaya pristan
# Processing record 387 : joinville
# Processing record 388 : sola
# Processing record 389 : mananjary
# Processing record 390 : inverell
# Processing record 391 : mayumba
# Processing record 392 : manggar
# Processing record 393 : lekoni
# Processing record 394 : solnechnyy
# Processing record 395 : kilifi
# Processing record 396 : boende
# Processing record 397 : tecoanapa
# Processing record 398 : ambilobe
# Processing record 399 : atasu
# Processing record 400 : porto seguro
# Processing record 401 : eureka
# Processing record 402 : gamba
# Processing record 403 : mozarlandia
# Processing record 404 : bud
# Processing record 405 : darlowo
# Processing record 406 : graaff-reinet
# Processing record 407 : zarubino
# Processing record 408 : lata
# Processing record 409 : coos bay
# Processing record 410 : lorengau
# Processing record 411 : viedma
# Processing record 412 : saint-joseph
# Processing record 413 : great yarmouth
# Processing record 414 : skjervoy
# Processing record 415 : martapura
# Processing record 416 : bodden town
# Processing record 417 : yeppoon
# Processing record 418 : sao filipe
# Processing record 419 : dingle
# Processing record 420 : namatanai
# Processing record 421 : chabahar
# Processing record 422 : voiron
# Processing record 423 : buin
# Processing record 424 : serebryansk
# Processing record 425 : kalmunai
# Processing record 426 : luderitz
# Processing record 427 : aswan
# Processing record 428 : waddan
# Processing record 429 : maragogi
# Processing record 430 : xichang
# Processing record 431 : evora
# Processing record 432 : ulagan
# Processing record 433 : matagami
# Processing record 434 : nuevo progreso
# Processing record 435 : vaitupu
# City not found. Skipping...: vaitupu
# Processing record 436 : vallenar
# Processing record 437 : elizabethton
# Processing record 438 : derzhavinsk
# Processing record 439 : naze
# Processing record 440 : sinnamary
# Processing record 441 : glendive
# Processing record 442 : blagoyevo
# Processing record 443 : vila franca do campo
# Processing record 444 : kandrian
# Processing record 445 : kahului
# Processing record 446 : carbonia
# Processing record 447 : vanavara
# Processing record 448 : conil
# Processing record 449 : batang berjuntai
# Processing record 450 : prince rupert
# Processing record 451 : mosquera
# Processing record 452 : buluang
# Processing record 453 : kishi
# Processing record 454 : necochea
# Processing record 455 : copiapo
# Processing record 456 : savonlinna
# Processing record 457 : hualmay
# Processing record 458 : kieta
# Processing record 459 : airai
# Processing record 460 : grand centre
# City not found. Skipping...: grand centre
# Processing record 461 : naftah
# City not found. Skipping...: naftah
# Processing record 462 : arraial do cabo
# Processing record 463 : portland
# Processing record 464 : catanzaro
# Processing record 465 : srednekolymsk
# Processing record 466 : balgazyn
# Processing record 467 : la primavera
# Processing record 468 : syracuse
# Processing record 469 : urucara
# Processing record 470 : coulommiers
# Processing record 471 : zhob
# Processing record 472 : tasbuget
# City not found. Skipping...: tasbuget
# Processing record 473 : huanren
# Processing record 474 : artyom
# Processing record 475 : turayf
# Processing record 476 : cherdyn
# Processing record 477 : angoche
# Processing record 478 : deputatskiy
# Processing record 479 : pangai
# Processing record 480 : williams lake
# Processing record 481 : snasa
# Processing record 482 : pozo colorado
# Processing record 483 : bonthe
# Processing record 484 : nguiu
# City not found. Skipping...: nguiu
# Processing record 485 : piranshahr
# Processing record 486 : meadow lake
# Processing record 487 : meulaboh
# Processing record 488 : krasnoborsk
# Processing record 489 : susanville
# Processing record 490 : oksfjord
# Processing record 491 : victoria
# Processing record 492 : zhigansk
# Processing record 493 : celestun
# Processing record 494 : samana
# Processing record 495 : bundaberg
# Processing record 496 : krasnodon
# Processing record 497 : manchester
# Processing record 498 : giddalur
# Processing record 499 : gaoyou
# Processing record 500 : taltal
# Processing record 501 : tuatapere
# Processing record 502 : lolua
# City not found. Skipping...: lolua
# Processing record 503 : pokhara
# Processing record 504 : shchelyayur
# City not found. Skipping...: shchelyayur
# Processing record 505 : bogandinskiy
# Processing record 506 : muzhi
# Processing record 507 : aksarka
# Processing record 508 : corona
# Processing record 509 : mingyue
# Processing record 510 : tateyama
# Processing record 511 : muros
# Processing record 512 : kenai
# Processing record 513 : manzanillo
# Processing record 514 : hofn
# Processing record 515 : jiddah
# City not found. Skipping...: jiddah
# Processing record 516 : el rodeo
# Processing record 517 : dickinson
# Processing record 518 : samarinda
# Processing record 519 : zhanatas
# City not found. Skipping...: zhanatas
# Processing record 520 : komsomolskiy
# Processing record 521 : samarai
# Processing record 522 : gerash
# Processing record 523 : dubinino
# Processing record 524 : aldama
# Processing record 525 : kongolo
# Processing record 526 : cavalcante
# Processing record 527 : narsaq
# Processing record 528 : leghorn
# City not found. Skipping...: leghorn
# Processing record 529 : ixtapa
# Processing record 530 : tres de maio
# Processing record 531 : rockhampton
# Processing record 532 : lazaro cardenas
# Processing record 533 : chihuahua
# Processing record 534 : tulsipur
# Processing record 535 : orebro
# Processing record 536 : kawalu
# Processing record 537 : nyurba
# Processing record 538 : geraldton
# Processing record 539 : cayenne
# Processing record 540 : jinchengjiang
# City not found. Skipping...: jinchengjiang
# Processing record 541 : mattru
# Processing record 542 : hastings
# Processing record 543 : jimo
# Processing record 544 : wanning
# Processing record 545 : elizabeth city
# Processing record 546 : ilembula
# Processing record 547 : lashio
# Processing record 548 : zanjan
# Processing record 549 : ahipara
# Processing record 550 : hirara
# Processing record 551 : dwarka
# Processing record 552 : te anau
# Processing record 553 : saryshagan
# City not found. Skipping...: saryshagan
# Processing record 554 : morondava
# Processing record 555 : beyneu
# Processing record 556 : mandera
# Processing record 557 : esmeralda
# Processing record 558 : kamenskoye
# City not found. Skipping...: kamenskoye
# Processing record 559 : george town
# Processing record 560 : huarmey
# Processing record 561 : ouadda
# Processing record 562 : anshun
# Processing record 563 : dicabisagan
# Processing record 564 : salihorsk
# Processing record 565 : pangody
# Processing record 566 : keflavik
# Processing record 567 : taseyevo
# Processing record 568 : san vicente
# Processing record 569 : sindor
# Processing record 570 : kavieng
# Processing record 571 : marawi
# Processing record 572 : la rioja
# Processing record 573 : walvis bay
# Processing record 574 : dong xoai
# Processing record 575 : leua
# Processing record 576 : unai
# Processing record 577 : karatau
# Processing record 578 : sidi ali
# Processing record 579 : zaysan
# Processing record 580 : bakel
# Processing record 581 : bintulu
# Processing record 582 : vila
# Processing record 583 : brainerd
# Processing record 584 : great bend
# Processing record 585 : marquette
# Processing record 586 : kazalinsk
# City not found. Skipping...: kazalinsk
# Processing record 587 : ulaanbaatar
# Processing record 588 : yaizu
# Processing record 589 : oranjemund
# Processing record 590 : khorramshahr
# Processing record 591 : bengkulu
# City not found. Skipping...: bengkulu
# ---------------------------------------
# Processing Complete

# %%
latitude = []
longitude = []
temperature = []
humidity = []
cloudiness = []
wind_speed = []
dates = []
for data in search_data:
    latitude.append(data.get("coord").get("lat"))
    longitude.append(data.get("coord").get("lon"))
    temperature.append(data.get("main").get("temp"))
    humidity.append(data.get("main").get("humidity"))
    cloudiness.append(data.get("clouds").get("all"))
    wind_speed.append(data.get("wind").get("speed"))
    dates.append(data.get("dt"))

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
print(f"City      {len(cityList)}")
print(f"Lat       {len(latitude)}")
print(f"Lng       {len(longitude)}")
print(f"Max Temp  {len(temperature)}")
print(f"Humidity  {len(humidity)}")
print(f"Cloudiness{len(cloudiness)}")
print(f"Wind Speed{len(wind_speed)}")
print(f"Date      {len(dates)}")
print(f"Country   {len(countryList)}")
# Out:
# City      527
# Lat       527
# Lng       527
# Max Temp  527
# Humidity  527
# Cloudiness527
# Wind Speed527
# Date      527
# Country   527

# %%
weather_df = pd.DataFrame({"City": cityList,
                           "Latitude": latitude,
                           "Longitude": longitude,
                           "Humidity": humidity,
                           "Max Temp": temperature,
                           "Cloudiness": cloudiness,
                           "Wind Speed": wind_speed,
                           "Date": dates,
                            })
weather_df.head()
# Out:
#          City  Latitude  Longitude  Humidity  Max Temp  Cloudiness  \
# 0     cascais     38.70      -9.42        87     48.16          20
# 1      talara     -4.58     -81.27        77     72.83          24
# 2  port blair     11.67      92.75       100     82.50          32
# 3      castro    -42.48     -73.76        93     51.80          75
# 4    katsuura     33.93     134.50        91     45.41          75
#
#    Wind Speed        Date
# 0        3.36  1544749200
# 1        6.20  1544752460
# 2       21.74  1544752179
# 3        3.36  1544749200
# 4       11.41  1544749200

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
plt.scatter(weather_df["Latitude"], weather_df["Max Temp"], marker="o",color='cyan',edgecolors='b')

plt.title("City Latitude vs Max Temperature(12/13/18)")
plt.ylabel("Max Temperature (F) ")
plt.xlabel("Latitude")
plt.grid(True)
plt.xlim(-70,90)

plt.show()

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
plt.scatter(weather_df["Latitude"], weather_df["Humidity"], marker="o",color='cyan',edgecolors='b')

plt.title("City Latitude vs Humidity(12/13/18)")
plt.ylabel("Humidity (%) ")
plt.xlabel("Latitude")
plt.grid(True)
plt.xlim(-70,90)

plt.show()

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
plt.scatter(weather_df["Latitude"], weather_df["Cloudiness"], marker="o",color='cyan',edgecolors='b')

plt.title("City Latitude vs Cloudiness(12/13/18)")
plt.ylabel("Cloudiness (%) ")
plt.xlabel("Latitude")
plt.grid(True)
plt.xlim(-70,90)

plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
plt.scatter(weather_df["Latitude"], weather_df["Wind Speed"], marker="o",color='cyan',edgecolors='b')

plt.title("City Latitude vs Wind Speed(12/13/18)")
plt.ylabel("Wind Speed (mph) ")
plt.xlabel("Latitude")
plt.grid(True)
plt.xlim(-70,90)

plt.show()
